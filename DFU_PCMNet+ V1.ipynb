# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.metrics import BinaryAccuracy, FalsePositives, FalseNegatives, TruePositives, TrueNegatives, Precision, Recall, AUC
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB1
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
labels = ['Abnormal(Ulcer)','Normal(Healthy skin)']

# %%
X_train = []
y_train = []
image_size = 224
for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/DFUEffectiveNet Dataset','train',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        try:
            img = cv2.resize(img,(image_size, image_size))
        except:
            break
        X_train.append(img)
        y_train.append(i)
        
for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/DFUEffectiveNet Dataset','test',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        y_train.append(i)
        
X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 1740/1740 [00:22<00:00, 77.40it/s]
# 100%|██████████| 1170/1170 [00:13<00:00, 84.26it/s]
# 100%|██████████| 170/170 [00:01<00:00, 102.68it/s]
# 100%|██████████| 110/110 [00:00<00:00, 132.44it/s]

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=1010)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=1010)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)


y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
import keras
import keras.utils
from keras import utils as np_utils
import numpy as np
from keras import layers
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
import pydot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils.vis_utils import plot_model
import keras.backend as k
from keras.initializers import glorot_uniform
import scipy.misc
from matplotlib.pyplot import imshow
from keras.utils.vis_utils import plot_model
from keras.initializers import glorot_uniform
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D

# %%
k.clear_session()
def inception_module(x, f1, f2):
		# 1x1 conv
		conv1 = keras.layers.Conv2D(f1, (1,1), strides=(1, 1), padding='same', activation='relu')(x)
		# 3x3 conv
		conv3 = keras.layers.Conv2D(f2, (3,3), strides=(1, 1), padding='same', activation='relu')(x)
		x = keras.layers.merge.concatenate([conv1, conv3])
		return x

# %%
def conv2d_bn(x,filters,num_row,num_col,padding='same',strides=(1, 1)):
   
    x = keras.layers.Conv2D(filters, (num_row, num_col),strides=strides,padding=padding)(x)
    x = keras.layers.BatchNormalization(axis=3, scale=False)(x)
    x = keras.layers.Activation('relu')(x)
    return x

# %% [markdown]
# Model Build

# %%
img_input = keras.Input(shape=(224, 224, 3))  #shape=(None, 299, 299, 3)

# %%
#OURmODELv6
#conv2d_bn(x,filters,num_row,num_col,padding='same',strides=(1, 1))
x = conv2d_bn(img_input, 64, 7, 7, strides=(2, 2), padding='same') # 149 x 149 x 32
x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2))(x)   # 73  x 73 x 64

x = conv2d_bn(x, 64, 1, 1, padding='same')  # 147 x 147 x 32
x = conv2d_bn(x, 192, 3, 3, padding='same') # 147 x 147 x 64
x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2))(x)   # 73  x 73 x 64

#inception_module(x, f1, f2, f3)
x = inception_module(x, 128, 128)
x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2))(x)  # 35 x 35 x 512

x = inception_module(x, 192, 192)
x = inception_module(x, 256, 256)
x = inception_module(x, 256, 256)
x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2))(x)  # 35 x 35 x 512

x = inception_module(x, 512, 512)
x = keras.layers.MaxPooling2D((7, 7), strides=(1, 1))(x)  # 35 x 35 x 192

#x = keras.layers.GlobalAveragePooling2D(name='avg_pool')(x) # shape=(None, 2048)
x = Flatten()(x)
x = keras.layers.Dense(1000, activation='relu')(x)
x = keras.layers.Dropout(0.5)(x)
x = keras.layers.Dense(2, activation='softmax', name='predictions')(x) #shape=(None, 1000)

# %%
# Create model.
inputs = img_input
model =  keras.Model(inputs, x, name='DFUEffectiveNetV1')
model.summary()


# plot model architecture
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True, to_file='DFUEffectiveNetV1.png')
# Out:
# Model: "DFUEffectiveNetV1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 64  192        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 112, 112, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['activation[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   4160        ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 64)  192         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 192)  110784      ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 56, 56, 192)  576        ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 56, 56, 192)  0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 192)  0          ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 128)  24704       ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 128)  221312      ['max_pooling2d_1[0][0]']
#
#  concatenate (Concatenate)      (None, 28, 28, 256)  0           ['conv2d_3[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 14, 14, 256)  0          ['concatenate[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 14, 14, 192)  49344       ['max_pooling2d_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 14, 14, 192)  442560      ['max_pooling2d_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 14, 14, 384)  0           ['conv2d_5[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 14, 14, 256)  98560       ['concatenate_1[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 14, 14, 256)  884992      ['concatenate_1[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 14, 14, 512)  0           ['conv2d_7[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 14, 14, 256)  131328      ['concatenate_2[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 14, 14, 256)  1179904     ['concatenate_2[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 14, 14, 512)  0           ['conv2d_9[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 512)   0           ['concatenate_3[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 7, 7, 512)    262656      ['max_pooling2d_3[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 7, 7, 512)    2359808     ['max_pooling2d_3[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 7, 7, 1024)   0           ['conv2d_11[0][0]',
#                                                                   'conv2d_12[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 1, 1, 1024)  0           ['concatenate_4[0][0]']
#
#  flatten (Flatten)              (None, 1024)         0           ['max_pooling2d_4[0][0]']
#
#  dense (Dense)                  (None, 1000)         1025000     ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 1000)         0           ['dense[0][0]']
#
#  predictions (Dense)            (None, 2)            2002        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 6,807,546
# Trainable params: 6,806,906
# Non-trainable params: 640
# __________________________________________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer = 'adam', metrics= 'accuracy')

# %%
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("DFUEffectiveNetV1.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.4, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)

# %%
history = model.fit(X_train,y_train,validation_split=0.05, epochs =50, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/50
# 86/86 [==============================] - ETA: 0s - loss: 0.7003 - accuracy: 0.7561
# Epoch 1: val_accuracy improved from -inf to 0.86111, saving model to DFUEffectiveNetV1.h5
# 86/86 [==============================] - 19s 92ms/step - loss: 0.7003 - accuracy: 0.7561 - val_loss: 0.4961 - val_accuracy: 0.8611 - lr: 0.0010
# Epoch 2/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.3193 - accuracy: 0.8743
# Epoch 2: val_accuracy did not improve from 0.86111
# 86/86 [==============================] - 6s 73ms/step - loss: 0.3193 - accuracy: 0.8739 - val_loss: 0.4269 - val_accuracy: 0.7986 - lr: 0.0010
# Epoch 3/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.2571 - accuracy: 0.8971
# Epoch 3: val_accuracy did not improve from 0.86111
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
# 86/86 [==============================] - 6s 71ms/step - loss: 0.2573 - accuracy: 0.8970 - val_loss: 0.3446 - val_accuracy: 0.8264 - lr: 0.0010
# Epoch 4/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.1966 - accuracy: 0.9217
# Epoch 4: val_accuracy improved from 0.86111 to 0.96528, saving model to DFUEffectiveNetV1.h5
# 86/86 [==============================] - 6s 75ms/step - loss: 0.1964 - accuracy: 0.9219 - val_loss: 0.1615 - val_accuracy: 0.9653 - lr: 4.0000e-04
# Epoch 5/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.1631 - accuracy: 0.9379
# Epoch 5: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 6s 71ms/step - loss: 0.1633 - accuracy: 0.9377 - val_loss: 0.1726 - val_accuracy: 0.9375 - lr: 4.0000e-04
# Epoch 6/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.1562 - accuracy: 0.9386
# Epoch 6: val_accuracy did not improve from 0.96528
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00016000000759959222.
# 86/86 [==============================] - 6s 72ms/step - loss: 0.1558 - accuracy: 0.9388 - val_loss: 0.2202 - val_accuracy: 0.8958 - lr: 4.0000e-04
# Epoch 7/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.1067 - accuracy: 0.9588
# Epoch 7: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 6s 72ms/step - loss: 0.1064 - accuracy: 0.9589 - val_loss: 0.1292 - val_accuracy: 0.9583 - lr: 1.6000e-04
# Epoch 8/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0922 - accuracy: 0.9684
# Epoch 8: val_accuracy did not improve from 0.96528
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 6.40000042039901e-05.
# 86/86 [==============================] - 6s 73ms/step - loss: 0.0925 - accuracy: 0.9681 - val_loss: 0.1890 - val_accuracy: 0.9167 - lr: 1.6000e-04
# Epoch 9/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0734 - accuracy: 0.9735
# Epoch 9: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 6s 73ms/step - loss: 0.0735 - accuracy: 0.9736 - val_loss: 0.1158 - val_accuracy: 0.9583 - lr: 6.4000e-05
# Epoch 10/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0571 - accuracy: 0.9812
# Epoch 10: val_accuracy did not improve from 0.96528
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.560000284574926e-05.
# 86/86 [==============================] - 6s 73ms/step - loss: 0.0570 - accuracy: 0.9813 - val_loss: 0.1224 - val_accuracy: 0.9653 - lr: 6.4000e-05
# Epoch 11/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0511 - accuracy: 0.9842
# Epoch 11: val_accuracy did not improve from 0.96528
# 86/86 [==============================] - 6s 74ms/step - loss: 0.0510 - accuracy: 0.9842 - val_loss: 0.1108 - val_accuracy: 0.9583 - lr: 2.5600e-05
# Epoch 12/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0421 - accuracy: 0.9882
# Epoch 12: val_accuracy improved from 0.96528 to 0.97222, saving model to DFUEffectiveNetV1.h5
# 86/86 [==============================] - 7s 77ms/step - loss: 0.0420 - accuracy: 0.9883 - val_loss: 0.0987 - val_accuracy: 0.9722 - lr: 2.5600e-05
# Epoch 13/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0415 - accuracy: 0.9879
# Epoch 13: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 6s 74ms/step - loss: 0.0417 - accuracy: 0.9875 - val_loss: 0.1096 - val_accuracy: 0.9653 - lr: 2.5600e-05
# Epoch 14/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0424 - accuracy: 0.9857
# Epoch 14: val_accuracy did not improve from 0.97222
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.0240000847261399e-05.
# 86/86 [==============================] - 6s 74ms/step - loss: 0.0423 - accuracy: 0.9857 - val_loss: 0.1166 - val_accuracy: 0.9583 - lr: 2.5600e-05
# Epoch 15/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0341 - accuracy: 0.9901
# Epoch 15: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 6s 74ms/step - loss: 0.0343 - accuracy: 0.9901 - val_loss: 0.1120 - val_accuracy: 0.9722 - lr: 1.0240e-05
# Epoch 16/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0350 - accuracy: 0.9890
# Epoch 16: val_accuracy did not improve from 0.97222
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.09600033890456e-06.
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0349 - accuracy: 0.9890 - val_loss: 0.1259 - val_accuracy: 0.9653 - lr: 1.0240e-05
# Epoch 17/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0298 - accuracy: 0.9912
# Epoch 17: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0298 - accuracy: 0.9912 - val_loss: 0.1157 - val_accuracy: 0.9722 - lr: 4.0960e-06
# Epoch 18/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0313 - accuracy: 0.9915
# Epoch 18: val_accuracy did not improve from 0.97222
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.6384001355618238e-06.
# 86/86 [==============================] - 6s 76ms/step - loss: 0.0321 - accuracy: 0.9908 - val_loss: 0.1096 - val_accuracy: 0.9722 - lr: 4.0960e-06
# Epoch 19/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0304 - accuracy: 0.9912
# Epoch 19: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0303 - accuracy: 0.9912 - val_loss: 0.1145 - val_accuracy: 0.9722 - lr: 1.6384e-06
# Epoch 20/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0340 - accuracy: 0.9908
# Epoch 20: val_accuracy did not improve from 0.97222
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 6.553600542247295e-07.
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0339 - accuracy: 0.9908 - val_loss: 0.1175 - val_accuracy: 0.9722 - lr: 1.6384e-06
# Epoch 21/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0334 - accuracy: 0.9923
# Epoch 21: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0343 - accuracy: 0.9919 - val_loss: 0.1173 - val_accuracy: 0.9722 - lr: 6.5536e-07
# Epoch 22/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0285 - accuracy: 0.9930
# Epoch 22: val_accuracy did not improve from 0.97222
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 2.6214402168989184e-07.
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0305 - accuracy: 0.9927 - val_loss: 0.1155 - val_accuracy: 0.9722 - lr: 6.5536e-07
# Epoch 23/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0326 - accuracy: 0.9923
# Epoch 23: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 6s 74ms/step - loss: 0.0326 - accuracy: 0.9923 - val_loss: 0.1147 - val_accuracy: 0.9722 - lr: 2.6214e-07
# Epoch 24/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0336 - accuracy: 0.9901
# Epoch 24: val_accuracy did not improve from 0.97222
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.0485761094969349e-07.
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0335 - accuracy: 0.9901 - val_loss: 0.1150 - val_accuracy: 0.9722 - lr: 2.6214e-07
# Epoch 25/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0322 - accuracy: 0.9901
# Epoch 25: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 6s 74ms/step - loss: 0.0321 - accuracy: 0.9901 - val_loss: 0.1144 - val_accuracy: 0.9722 - lr: 1.0486e-07
# Epoch 26/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0269 - accuracy: 0.9930
# Epoch 26: val_accuracy did not improve from 0.97222
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 4.1943044948311586e-08.
# 86/86 [==============================] - 6s 74ms/step - loss: 0.0295 - accuracy: 0.9927 - val_loss: 0.1143 - val_accuracy: 0.9722 - lr: 1.0486e-07
# Epoch 27/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0318 - accuracy: 0.9926
# Epoch 27: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 6s 74ms/step - loss: 0.0318 - accuracy: 0.9927 - val_loss: 0.1138 - val_accuracy: 0.9722 - lr: 4.1943e-08
# Epoch 28/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0293 - accuracy: 0.9904
# Epoch 28: val_accuracy did not improve from 0.97222
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.677721854775882e-08.
# 86/86 [==============================] - 6s 74ms/step - loss: 0.0292 - accuracy: 0.9905 - val_loss: 0.1141 - val_accuracy: 0.9722 - lr: 4.1943e-08
# Epoch 29/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0316 - accuracy: 0.9901
# Epoch 29: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0320 - accuracy: 0.9897 - val_loss: 0.1143 - val_accuracy: 0.9722 - lr: 1.6777e-08
# Epoch 30/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0312 - accuracy: 0.9915
# Epoch 30: val_accuracy did not improve from 0.97222
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 6.710887134886434e-09.
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0311 - accuracy: 0.9916 - val_loss: 0.1141 - val_accuracy: 0.9722 - lr: 1.6777e-08
# Epoch 31/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0327 - accuracy: 0.9919
# Epoch 31: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0327 - accuracy: 0.9919 - val_loss: 0.1142 - val_accuracy: 0.9722 - lr: 6.7109e-09
# Epoch 32/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0302 - accuracy: 0.9919
# Epoch 32: val_accuracy did not improve from 0.97222
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 2.6843547829003003e-09.
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0301 - accuracy: 0.9919 - val_loss: 0.1138 - val_accuracy: 0.9722 - lr: 6.7109e-09
# Epoch 33/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0306 - accuracy: 0.9901
# Epoch 33: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0305 - accuracy: 0.9901 - val_loss: 0.1136 - val_accuracy: 0.9722 - lr: 2.6844e-09
# Epoch 34/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0271 - accuracy: 0.9926
# Epoch 34: val_accuracy did not improve from 0.97222
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.0737418953965518e-09.
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0272 - accuracy: 0.9927 - val_loss: 0.1131 - val_accuracy: 0.9722 - lr: 2.6844e-09
# Epoch 35/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0297 - accuracy: 0.9908
# Epoch 35: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0302 - accuracy: 0.9905 - val_loss: 0.1137 - val_accuracy: 0.9722 - lr: 1.0737e-09
# Epoch 36/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0297 - accuracy: 0.9912
# Epoch 36: val_accuracy did not improve from 0.97222
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 4.294967492768365e-10.
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0296 - accuracy: 0.9912 - val_loss: 0.1128 - val_accuracy: 0.9722 - lr: 1.0737e-09
# Epoch 37/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0281 - accuracy: 0.9923
# Epoch 37: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0286 - accuracy: 0.9919 - val_loss: 0.1135 - val_accuracy: 0.9722 - lr: 4.2950e-10
# Epoch 38/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0312 - accuracy: 0.9919
# Epoch 38: val_accuracy did not improve from 0.97222
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.7179869749028854e-10.
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0312 - accuracy: 0.9919 - val_loss: 0.1135 - val_accuracy: 0.9722 - lr: 4.2950e-10
# Epoch 39/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0292 - accuracy: 0.9937
# Epoch 39: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0292 - accuracy: 0.9938 - val_loss: 0.1136 - val_accuracy: 0.9722 - lr: 1.7180e-10
# Epoch 40/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0332 - accuracy: 0.9897
# Epoch 40: val_accuracy did not improve from 0.97222
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 6.871948010633844e-11.
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0332 - accuracy: 0.9897 - val_loss: 0.1143 - val_accuracy: 0.9722 - lr: 1.7180e-10
# Epoch 41/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0345 - accuracy: 0.9897
# Epoch 41: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 7s 76ms/step - loss: 0.0346 - accuracy: 0.9897 - val_loss: 0.1139 - val_accuracy: 0.9722 - lr: 6.8719e-11
# Epoch 42/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0323 - accuracy: 0.9904
# Epoch 42: val_accuracy did not improve from 0.97222
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 2.748779259764689e-11.
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0323 - accuracy: 0.9905 - val_loss: 0.1141 - val_accuracy: 0.9722 - lr: 6.8719e-11
# Epoch 43/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0323 - accuracy: 0.9915
# Epoch 43: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0344 - accuracy: 0.9908 - val_loss: 0.1150 - val_accuracy: 0.9722 - lr: 2.7488e-11
# Epoch 44/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0312 - accuracy: 0.9915
# Epoch 44: val_accuracy did not improve from 0.97222
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.0995117316614512e-11.
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0314 - accuracy: 0.9912 - val_loss: 0.1149 - val_accuracy: 0.9722 - lr: 2.7488e-11
# Epoch 45/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0334 - accuracy: 0.9893
# Epoch 45: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0334 - accuracy: 0.9894 - val_loss: 0.1148 - val_accuracy: 0.9722 - lr: 1.0995e-11
# Epoch 46/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0320 - accuracy: 0.9897
# Epoch 46: val_accuracy did not improve from 0.97222
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 4.398046857256866e-12.
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0320 - accuracy: 0.9897 - val_loss: 0.1141 - val_accuracy: 0.9722 - lr: 1.0995e-11
# Epoch 47/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0328 - accuracy: 0.9901
# Epoch 47: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0327 - accuracy: 0.9901 - val_loss: 0.1143 - val_accuracy: 0.9722 - lr: 4.3980e-12
# Epoch 48/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0318 - accuracy: 0.9897
# Epoch 48: val_accuracy did not improve from 0.97222
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.7592188122916854e-12.
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0318 - accuracy: 0.9897 - val_loss: 0.1141 - val_accuracy: 0.9722 - lr: 4.3980e-12
# Epoch 49/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0323 - accuracy: 0.9897
# Epoch 49: val_accuracy did not improve from 0.97222
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0322 - accuracy: 0.9897 - val_loss: 0.1148 - val_accuracy: 0.9722 - lr: 1.7592e-12
# Epoch 50/50
# 85/86 [============================>.] - ETA: 0s - loss: 0.0277 - accuracy: 0.9919
# Epoch 50: val_accuracy did not improve from 0.97222
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 7.036875422639088e-13.
# 86/86 [==============================] - 6s 75ms/step - loss: 0.0278 - accuracy: 0.9919 - val_loss: 0.1137 - val_accuracy: 0.9722 - lr: 1.7592e-12

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy',fontweight='bold')
plt.xlim([0,50])
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy',fontweight='bold', fontsize=14)
plt.xlabel('Epochs',fontweight='bold')
# plt.legend(loc='best')
plt.savefig('DFUEffectiveNetV1TV1',dpi=400)
plt.show()

# %%
filterwarnings('ignore')

epochs = [i for i in range(50)]
fig, ax = plt.subplots(1,2,figsize=(30,15))
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

fig.text(s='Epochs vs. Training and Validation Accuracy/Loss',size=14,fontweight='bold',
             fontname='monospace',color='#313131',y=1,x=0.28,alpha=0.8)

sns.despine()
ax[0].plot(epochs, train_acc, marker='o',markerfacecolor='#4F7942',color='#74C365',
           label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, marker='o',markerfacecolor='#9E1717',color='#D35151',
           label = 'Validation Accuracy')
ax[0].legend(frameon=False)
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Training & Validation Accuracy')

sns.despine()
ax[1].plot(epochs, train_loss, marker='*',markerfacecolor='#4F7942',color='#74C365',
           label ='Training Loss')
ax[1].plot(epochs, val_loss, marker='*',markerfacecolor='#9E1717',color='#D35151',
           label = 'Validation Loss')
ax[1].legend(frameon=False)
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Training & Validation Loss')
plt.savefig('DFUEffectiveNetV1TV2',dpi=700)
fig.show()

# %%
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)

# %%
print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       195
#            1       0.94      0.90      0.92       124
#
#     accuracy                           0.94       319
#    macro avg       0.94      0.93      0.93       319
# weighted avg       0.94      0.94      0.94       319

# %%
cm = confusion_matrix(y_test_new, pred)

# %%
import itertools
from itertools import product
def plot_confusion_matrix(cm, classes,normalize=False,title='Confusion matrix',cmap=plt.cm.Blues):
    
    plt.figure(figsize=(7,5))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=40)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True/Actual label')
    plt.xlabel('Predicted label')

plot_confusion_matrix(cm,labels)
plt.savefig('DFUEffectiveNetV1CM',dpi=400)
# Out:
# Confusion matrix, without normalization

# %%
TP=cm[1,1]
TN=cm[0,0]
FP=cm[0,1]
FN=cm[1,0]

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score,confusion_matrix, roc_curve, auc,roc_auc_score

print('Accuracy: %.3f' % accuracy_score(y_test_new, pred), 'Precision: %.3f' % precision_score(y_test_new, pred),' Recall: %.3f' % recall_score(y_test_new, pred), 
      'F1 Score: %.3f' % f1_score(y_test_new, pred), 'AUC Score: %.3f' % roc_auc_score(y_test_new, pred))
# Out:
# Accuracy: 0.937 Precision: 0.941  Recall: 0.895 F1 Score: 0.917 AUC Score: 0.930

# %%
recall=TP/float(TP+FN)
print(recall)
print(recall_score(y_test_new, pred))
# Out:
# 0.8951612903225806
# 0.8951612903225806

# %%
precision=TP/float(TP+FP)
print(precision)

print(precision_score(y_test_new, pred))
# Out:
# 0.940677966101695
# 0.940677966101695

# %%
print((2*precision*recall)/(recall+precision))
print(f1_score(y_test_new, pred))
# Out:
# 0.9173553719008264
# 0.9173553719008264

# %%
specificity=TN/float(TN+FP)
print(specificity)
# Out:
# 0.9641025641025641

# %%
print(TP/float(TP+FN))
print(recall_score(y_test_new, pred))
# Out:
# 0.8951612903225806
# 0.8951612903225806

# %%
print(roc_auc_score(y_test_new, pred))
# Out:
# 0.9296319272125723

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test_new, pred)
# Out:
# 0.06269592476489028

# %%
#Print Area Under Curve
false_positive_rate, recall, thresholds = roc_curve(y_test_new, pred)
roc_auc = auc(false_positive_rate, recall)
plt.figure()
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.plot(false_positive_rate, recall, 'b', label = 'AUC = %0.3f' %roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1], [0,1], 'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.0])
plt.ylabel('Recall')
plt.xlabel('Fall-out (1-Specificity)')
plt.show()

# %%
acc = accuracy_score(y_test_new, pred)*100
auc=roc_auc_score(y_test_new, pred)*100
tn, fp, fn, tp = cm.ravel()
precision = tp/(tp+fp)*100
recall = tp/(tp+fn)*100
specificity = tn/(tn+fp)*100
print('Accuracy: {0:0.2f}%'.format(acc))
print('Precision: {0:0.2f}%'.format(precision))
print('Recall or Sensitivity: {0:0.2f}%'.format(recall))
print('Specificity: {0:0.2f}%'.format(specificity))
print('F1-score: {0:0.2f}%'.format(2*precision*recall/(precision+recall)))
print('AUC-score: {0:0.2f}%'.format(auc))
print('Train acc: {0:0.2f}%'.format(np.round((history.history['accuracy'][-1])*100, 2)))
print('val_accuracy: {0:0.2f}%'.format(np.round((history.history['val_accuracy'][-1])*100, 2)))
# Out:
# Accuracy: 93.73%
# Precision: 94.07%
# Recall or Sensitivity: 89.52%
# Specificity: 96.41%
# F1-score: 91.74%
# AUC-score: 92.96%
# Train acc: 99.19%
# val_accuracy: 97.22%
